# %%
import rpa as r
import pandas as pd 
import time
import pickle

r.init()

URL = f'https://www.tripadvisor.com.sg/Restaurants-g294265-Singapore.html'
r.url(URL)
time.sleep(10)



maxpage = int(r.read('//*[@id="EATERY_LIST_CONTENTS"]/div[2]/div/div/a[6]/@data-page-number'))
for j in range (0,maxpage):
    URL_list = []
    if j!=0: 
        if r.present(f'(//*[@id="EATERY_LIST_CONTENTS"]/div[2]/div/a)[2]'):
            r.click(f'(//*[@id="EATERY_LIST_CONTENTS"]/div[2]/div/a)[2]')
        else:
            r.click(f'(//*[@id="EATERY_LIST_CONTENTS"]/div[2]/div/a)[1]')

    time.sleep(10)
    for i in range (1,100):
        if r.exist(f'(//*[@id="component_2"]/div/div[*]/span/div[1]/div[2]/div[1]/div/span/a/@href)[{i}]') == False: break
        URL_list.append("https://www.tripadvisor.com.sg" + r.read(f'(//*[@id="component_2"]/div/div[*]/span/div[1]/div[2]/div[1]/div/span/a/@href)[{i}]'))
        #print(URL_list)
        with open(f'url_list_{j}.txt', 'wb') as filehandle: pickle.dump(URL_list, filehandle)

# %%
import rpa as r
import pandas as pd 
import time
import pickle

r.init()
# Out:
# True

# %%
import pickle

with open('url_list_9.txt', 'rb') as filehandle: URL_list = pickle.load(filehandle)

print(URL_list[33])
# Out:
# https://www.tripadvisor.com.sg/Restaurant_Review-g294265-d3524902-Reviews-1919_Waterboat_House-Singapore.html

# %%
author_loc=""
for y in range (9,398):    
    with open(f'url_list_{y}.txt', 'rb') as filehandle: URL_list = pickle.load(filehandle)
    reviews_df=pd.DataFrame()
    if y == 9: init = 33
    else: init = 0
    for x in range (init,100):
        if len(URL_list) <= x: break
        r.url(URL_list[x])
        time.sleep(10)
        if r.present('//*[@id="taplc_detail_filters_rr_resp_0"]/div/div[1]/div/div[2]/div[4]/div/div[2]/div[1]/div[2]/label/span[2]') == False: continue
        num_reviews=r.read('//*[@id="taplc_detail_filters_rr_resp_0"]/div/div[1]/div/div[2]/div[4]/div/div[2]/div[1]/div[2]/label/span[2]')
        num_reviews=int(num_reviews.replace(' reviews','').replace(' review','').replace(',','').replace('(','').replace(')',''))
        #print(num_reviews)
        j=1
        while j <= num_reviews:
            r.click('//*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span')
            i0=0
            for i in range (1,11):
                name = r.read('//*[@data-test-target="top-info-header"]')
                location = ""
                address = r.read('//*/div/div[3]/span[1]/span/a')
                if r.present('//*/div/div[2]/span[3]/a[2]'):
                    type = r.read('//*/div/div[2]/span[3]/a[2]')+","+r.read('//*/div/div[2]/span[3]/a[3]')+","+r.read('//*/div/div[2]/span[3]/a[4]')
                else:
                    type = r.read('//*/div/div[2]/span[3]/a[1]') 
                if r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i}]').replace("ui_bubble_rating bubble_","") == '': break    
                if r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i}]').replace("ui_bubble_rating bubble_","") != 'ui_icon star-fill':
                    rating = int(r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i+i0}]').replace("ui_bubble_rating bubble_",""))/10
                else:
                    i0=1
                    rating = int(r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i+i0}]').replace("ui_bubble_rating bubble_",""))/10

                author = r.read(f'(//*[@class="memberOverlayLink clickable"]/div[2])[{i}]/div[1]')
                if r.exist(f'(//*[@class="memberOverlayLink clickable"]/div[2])[{i}]/div[2]'):
                    author_loc = r.read(f'(//*[@class="memberOverlayLink clickable"]/div[2])[{i}]/div[2]')
                date = r.read(f'(//*[@class="ratingDate"]/@title)[{i}]')
                review = r.read(f'(//*[contains(@id,"review")]/div/div/div[2]/div/p)[{i}]')
                origin = "TripAdvisor"
                #print(name)
                #print(location)
                #print(address)
                #print(type)
                #print(rating)
                #print(author)
                #print(author_loc)
                #print(date)
                #print(review)
                #print(origin)

                review_dict = {'restaurant' : name,
                        'location' : location,      
                        'address' : address,                           
                        'type' : type,               
                        'rating': rating, 
                        'author': author,
                        'author_loc': author_loc,                     
                        'date': date,
                        'Review': review,
                        'origin': origin,
                    }

                reviews_df = reviews_df.append(review_dict, ignore_index=True)
                reviews_df.to_csv(f'{y}.csv', sep=',')

                j=j+1
                if j>num_reviews: break
            if num_reviews>j: r.click('//*[contains(@class,"next ui_button")]')
# Out:
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[3]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# ...
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[4]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span

# %%
reviews_df.head(10)

# %%
print(j)

# %%
isinstance(r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i+i0}]').replace("ui_bubble_rating bubble_",""),int)

# %%
r.read(f'(//*[@class="memberOverlayLink clickable"]/div[2])[{i}]/div[1]')

# %%
r.click('//*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span')

# %%
print(num_reviews)

# %%
len(URL_list)

# %%
print(x)

# %%
import pandas as pd 

yelp=pd.read_csv("yelpindex.csv")
yelp["URL"].head
# Out:
# <bound method NDFrame.head of 0       https://www.google.com/search?q=The+Naked+Finn...
# 1       https://www.google.com/search?q=Uncle+Ho+Tucks...
# 2       https://www.google.com/search?q=John's+Pizzeri...
# 3       https://www.google.com/search?q=Keng+Eng+Kee+S...
# 4       https://www.google.com/search?q=BurgerLabo+Tri...
#                               ...
# 1982    https://www.google.com/search?q=Feng+Food+å°æ...
# 1983    https://www.google.com/search?q=The+Famous+Kit...
# 1984    https://www.google.com/search?q=Blk+925+AFE+Yi...
# 1985    https://www.google.com/search?q=State's+Wester...
# 1986    https://www.google.com/search?q=Blk+925+Yishun...
# Name: URL, Length: 1987, dtype: object>

# %%
import rpa as r
import pandas as pd 
import time
import pickle

r.init()
# Out:
# True

# %%
import time

for i in range (0,1987):
    r.url(yelp["URL"][i])
    if r.present("//*[@id='rso']/div[1]/div/div[1]/a/@href"): name = r.read("//*[@id='rso']/div[1]/div/div[1]/a/@href")
    else: name = r.read("//*[@id='rso']/div[2]/div/div[1]/a/@href")
    print(name)
    yelp["URL"][i] = name
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-44c2f1e74a35> in <module>
#       2
#       3 for i in range (0,1987):
# ----> 4     r.url(yelp["URL"][i])
#       5     if r.present("//*[@id='rso']/div[1]/div/div[1]/a/@href"): name = r.read("//*[@id='rso']/div[1]/div/div[1]/a/@href")
#       6     else: name = r.read("//*[@id='rso']/div[2]/div/div[1]/a/@href")
#
# NameError: name 'yelp' is not defined

# %%
yelp.to_csv("yelpindex_updated.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1f7a8887427d> in <module>
# ----> 1 yelp.to_csv("yelpindex_updated.csv")
#
# NameError: name 'yelp' is not defined

# %%
yelp2TA=pd.read_csv("yelpindex_updated.csv")
yelp2TA.reset_index(drop=True)
yelp2TA["URL"].head
# Out:
# <bound method NDFrame.head of 0      https://www.tripadvisor.co.nz/Restaurant_Revie...
# 1      https://www.tripadvisor.com/Restaurant_Review-...
# 2      https://www.tripadvisor.com/Restaurant_Review-...
# 3      https://www.tripadvisor.com/Restaurant_Review-...
# 4      https://www.tripadvisor.com/Restaurant_Review-...
# 5      https://www.tripadvisor.com/Restaurant_Review-...
# 6      https://www.tripadvisor.com.sg/Restaurant_Revi...
# 7      https://www.tripadvisor.com/Restaurant_Review-...
# 8      https://www.tripadvisor.com.sg/Restaurant_Revi...
# 9      https://www.tripadvisor.com/Restaurant_Review-...
# 10     https://www.tripadvisor.com/Restaurant_Review-...
# 11     https://www.tripadvisor.com/Restaurant_Review-...
# 12     https://www.tripadvisor.com/Restaurant_Review-...
# 13     https://www.tripadvisor.com/Restaurant_Review-...
# 14     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 15     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 16     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 17     https://www.tripadvisor.com/Restaurant_Review-...
# 18     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 19     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 20     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 21     https://www.tripadvisor.com/Restaurant_Review-...
# 22     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 23     https://www.tripadvisor.com/Restaurant_Review-...
# 24     https://www.tripadvisor.com/Restaurant_Review-...
# 25     https://en.tripadvisor.com.hk/Restaurant_Revie...
# 26     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 27     https://www.tripadvisor.com/Restaurant_Review-...
# 28     https://www.tripadvisor.com.sg/Restaurant_Revi...
# 29     https://www.tripadvisor.com.sg/Restaurant_Revi...
#                              ...
# 291    https://www.tripadvisor.com/Restaurant_Review-...
# 292    https://en.tripadvisor.com.hk/Restaurant_Revie...
# 293    https://www.tripadvisor.com/Restaurant_Review-...
# 294    https://www.tripadvisor.com/Restaurant_Review-...
# 295    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 296    https://www.tripadvisor.com/Restaurant_Review-...
# 297    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 298    https://www.tripadvisor.com/Restaurant_Review-...
# 299    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 300    https://www.tripadvisor.com/Restaurant_Review-...
# 301    https://www.tripadvisor.com/Restaurant_Review-...
# 302    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 303    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 304    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 305    https://www.tripadvisor.co.nz/Restaurant_Revie...
# 306    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 307    https://www.tripadvisor.com/Restaurant_Review-...
# 308    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 309    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 310    https://www.tripadvisor.co.nz/Restaurant_Revie...
# 311    https://www.tripadvisor.com/Restaurant_Review-...
# 312    https://www.tripadvisor.com/Restaurant_Review-...
# 313    https://www.tripadvisor.com/Restaurant_Review-...
# 314    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 315    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 316    https://www.tripadvisor.com/Restaurant_Review-...
# 317    https://www.tripadvisor.com.sg/Restaurant_Revi...
# 318    https://www.tripadvisor.com/Restaurant_Review-...
# 319    http://www.tripadvisor.co.nz/Restaurant_Review...
# 320    https://www.tripadvisor.com.sg/Restaurant_Revi...
# Name: URL, Length: 321, dtype: object>

# %%
yelp2TA["URL"][0]
# Out:
# 'https://www.tripadvisor.co.nz/Restaurant_Review-g294265-d12123036-r562032410-The_Other_Room-Singapore.html'

# %%
author_loc=""
reviews_df=pd.DataFrame()
#if y == 9: init = 33
#else: init = 0
for x in range (0,747):
    if len(yelp2TA["URL"]) <= x: break
    r.url(yelp2TA["URL"][x])
    time.sleep(10)
    if r.present('//*[@id="taplc_detail_filters_rr_resp_0"]/div/div[1]/div/div[2]/div[4]/div/div[2]/div[1]/div[2]/label/span[2]') == False: continue
    num_reviews=r.read('//*[@id="taplc_detail_filters_rr_resp_0"]/div/div[1]/div/div[2]/div[4]/div/div[2]/div[1]/div[2]/label/span[2]')
    num_reviews=int(num_reviews.replace(' reviews','').replace(' review','').replace(',','').replace('(','').replace(')',''))
    #print(num_reviews)
    j=1
    while j <= num_reviews or j<= 100:
        r.click('//*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span')
        r.click('//*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]')
        i0=0
        for i in range (1,11):
            name = yelp2TA["Name"][x]
            location = ""
            address = r.read('//*/div/div[3]/span[1]/span/a')
            if r.present('//*/div/div[2]/span[3]/a[4]'):
                type = r.read('//*/div/div[2]/span[3]/a[2]')+","+r.read('//*/div/div[2]/span[3]/a[3]')+","+r.read('//*/div/div[2]/span[3]/a[4]')
            elif r.present('//*/div/div[2]/span[3]/a[3]'):
                type = r.read('//*/div/div[2]/span[3]/a[2]')+","+r.read('//*/div/div[2]/span[3]/a[3]')
            elif r.present('//*/div/div[2]/span[3]/a[2]'):
                type = r.read('//*/div/div[2]/span[3]/a[2]')
            else:
                type = r.read('//*/div/div[2]/span[3]/a[1]') 
            if r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i}]').replace("ui_bubble_rating bubble_","") == '': break    
            if r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i}]').replace("ui_bubble_rating bubble_","") != 'ui_icon star-fill':
                rating = int(r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i+i0}]').replace("ui_bubble_rating bubble_",""))/10
            else:
                i0=1
                rating = int(r.read(f'(//*[contains(@id,"review")]/div/div/span[1]/@class)[{i+i0}]').replace("ui_bubble_rating bubble_",""))/10

            author = r.read(f'(//*[@class="memberOverlayLink clickable"]/div[2])[{i}]/div[1]')
            if r.exist(f'(//*[@class="memberOverlayLink clickable"]/div[2])[{i}]/div[2]'):
                author_loc = r.read(f'(//*[@class="memberOverlayLink clickable"]/div[2])[{i}]/div[2]')
            date = r.read(f'(//*[@class="ratingDate"]/@title)[{i}]')
            review = r.read(f'(//*[contains(@id,"review")]/div/div/div[2]/div/p)[{i}]')
            origin = "TripAdvisor"
            #print(name)
            #print(location)
            #print(address)
            #print(type)
            #print(rating)
            #print(author)
            #print(author_loc)
            #print(date)
            #print(review)
            #print(origin)

            review_dict = {'restaurant' : name,
                    'location' : location,      
                    'address' : address,                           
                    'type' : type,               
                    'rating': rating, 
                    'author': author,
                    'author_loc': author_loc,                     
                    'date': date,
                    'Review': review,
                    'origin': origin,
                }

            reviews_df = reviews_df.append(review_dict, ignore_index=True)
            reviews_df.to_csv(f'yelp2tripadvisor.csv', sep=',')

            j=j+1
            if j>num_reviews or j>100: break
        if j>num_reviews or j>100: break
        elif num_reviews>j: r.click('//*[contains(@class,"next ui_button")]')
# Out:
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[1]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[2]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[3]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[4]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[5]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[6]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[7]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[8]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[9]/div[1]
# [RPA][ERROR] - cannot find (//*[@class="memberOverlayLink clickable"]/div[2])[10]/div[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# [RPA][ERROR] - cannot find //*[contains(@class,"next ui_button")]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[1]
# ...
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/div[2]/div/p)[10]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[8]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[8]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[8]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[8]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[8]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[8]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[8]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[6]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/div[2]/div/p)[10]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[4]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[4]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[4]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[4]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/div[2]/div/p)[10]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/div[2]/div/p)[10]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/div[2]/div/p)[10]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[5]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[5]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find (//*[contains(@id,"review")]/div/div/span[1]/@class)[5]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*/div/div[3]/span[1]/span/a
# [RPA][ERROR] - cannot find //*/div/div[2]/span[3]/a[1]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]
# [RPA][ERROR] - cannot find //*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]

# %%
r.click('//*[contains(@id,"review")]/div/div[2]/div[2]/div/p/span[2]')
# Out:
# True
